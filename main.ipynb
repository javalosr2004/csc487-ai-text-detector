# %% [markdown]
# <a href="https://colab.research.google.com/github/javalosr2004/csc487-ai-text-detector/blob/main/main.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # CSC487 AI Text Detector
#
# Run all cells in order to pretrain → fine-tune → evaluate.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import torch
print(f"GPU Available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"GPU: {torch.cuda.get_device_name(0)}")

# %%
# !git clone https://github.com/javalosr2004/csc487-ai-text-detector.git
# %cd csc487-ai-text-detector

# %%
# %pip install -r requirements.txt

# %%
# !python pretraining.py --config configs/pretrain.yaml

# %%
PATH_TO_PRETRAINED_MODEL = ""

# %%
# !python train.py --config configs/train.yaml --checkpoint {PATH_TO_PRETRAINED_MODEL}

# %%
PATH_TO_FINAL_MODEL = ""

# %%
# !python eval.py --checkpoint {PATH_TO_FINAL_MODEL}

# %%
# !cp -r checkpoints /content/drive/MyDrive/

# %%
# !python inference.py --checkpoint {PATH_TO_FINAL_MODEL}
