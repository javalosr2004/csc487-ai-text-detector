# %%
import torch
print(f"GPU Available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"GPU: {torch.cuda.get_device_name(0)}")
# Out:
# GPU Available: False

# %%
# %pip install -r requirements.txt
# Out:
# Requirement already satisfied: torch>=2.0.0 in /Users/janitsharma/anaconda3/envs/ai_text_detection_env/lib/python3.11/site-packages (from -r requirements.txt (line 1)) (2.9.1)
# Requirement already satisfied: pandas>=2.0.0 in /Users/janitsharma/anaconda3/envs/ai_text_detection_env/lib/python3.11/site-packages (from -r requirements.txt (line 2)) (2.3.3)
# Requirement already satisfied: numpy>=1.24.0 in /Users/janitsharma/anaconda3/envs/ai_text_detection_env/lib/python3.11/site-packages (from -r requirements.txt (line 3)) (2.3.5)
# Requirement already satisfied: scikit-learn>=1.3.0 in /Users/janitsharma/anaconda3/envs/ai_text_detection_env/lib/python3.11/site-packages (from -r requirements.txt (line 4)) (1.7.2)
# Requirement already satisfied: matplotlib>=3.7.0 in /Users/janitsharma/anaconda3/envs/ai_text_detection_env/lib/python3.11/site-packages (from -r requirements.txt (line 5)) (3.10.7)
# Requirement already satisfied: pyyaml>=6.0 in /Users/janitsharma/anaconda3/envs/ai_text_detection_env/lib/python3.11/site-packages (from -r requirements.txt (line 6)) (6.0.3)
# Requirement already satisfied: transformers>=4.30.0 in /Users/janitsharma/anaconda3/envs/ai_text_detection_env/lib/python3.11/site-packages (from -r requirements.txt (line 7)) (4.57.3)
# Requirement already satisfied: filelock in /Users/janitsharma/anaconda3/envs/ai_text_detection_env/lib/python3.11/site-packages (from torch>=2.0.0->-r requirements.txt (line 1)) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /Users/janitsharma/anaconda3/envs/ai_text_detection_env/lib/python3.11/site-packages (from torch>=2.0.0->-r requirements.txt (line 1)) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in /Users/janitsharma/anaconda3/envs/ai_text_detection_env/lib/python3.11/site-packages (from torch>=2.0.0->-r requirements.txt (line 1)) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /Users/janitsharma/anaconda3/envs/ai_text_detection_env/lib/python3.11/site-packages (from torch>=2.0.0->-r requirements.txt (line 1)) (3.5)
# Requirement already satisfied: jinja2 in /Users/janitsharma/anaconda3/envs/ai_text_detection_env/lib/python3.11/site-packages (from torch>=2.0.0->-r requirements.txt (line 1)) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /Users/janitsharma/anaconda3/envs/ai_text_detection_env/lib/python3.11/site-packages (from torch>=2.0.0->-r requirements.txt (line 1)) (2025.10.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/janitsharma/anaconda3/envs/ai_text_detection_env/lib/python3.11/site-packages (from pandas>=2.0.0->-r requirements.txt (line 2)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/janitsharma/anaconda3/envs/ai_text_detection_env/lib/python3.11/site-packages (from pandas>=2.0.0->-r requirements.txt (line 2)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/janitsharma/anaconda3/envs/ai_text_detection_env/lib/python3.11/site-packages (from pandas>=2.0.0->-r requirements.txt (line 2)) (2025.2)
# Requirement already satisfied: scipy>=1.8.0 in /Users/janitsharma/anaconda3/envs/ai_text_detection_env/lib/python3.11/site-packages (from scikit-learn>=1.3.0->-r requirements.txt (line 4)) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in /Users/janitsharma/anaconda3/envs/ai_text_detection_env/lib/python3.11/site-packages (from scikit-learn>=1.3.0->-r requirements.txt (line 4)) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/janitsharma/anaconda3/envs/ai_text_detection_env/lib/python3.11/site-packages (from scikit-learn>=1.3.0->-r requirements.txt (line 4)) (3.6.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/janitsharma/anaconda3/envs/ai_text_detection_env/lib/python3.11/site-packages (from matplotlib>=3.7.0->-r requirements.txt (line 5)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Users/janitsharma/anaconda3/envs/ai_text_detection_env/lib/python3.11/site-packages (from matplotlib>=3.7.0->-r requirements.txt (line 5)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/janitsharma/anaconda3/envs/ai_text_detection_env/lib/python3.11/site-packages (from matplotlib>=3.7.0->-r requirements.txt (line 5)) (4.61.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/janitsharma/anaconda3/envs/ai_text_detection_env/lib/python3.11/site-packages (from matplotlib>=3.7.0->-r requirements.txt (line 5)) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /Users/janitsharma/anaconda3/envs/ai_text_detection_env/lib/python3.11/site-packages (from matplotlib>=3.7.0->-r requirements.txt (line 5)) (25.0)
# Requirement already satisfied: pillow>=8 in /Users/janitsharma/anaconda3/envs/ai_text_detection_env/lib/python3.11/site-packages (from matplotlib>=3.7.0->-r requirements.txt (line 5)) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in /Users/janitsharma/anaconda3/envs/ai_text_detection_env/lib/python3.11/site-packages (from matplotlib>=3.7.0->-r requirements.txt (line 5)) (3.2.5)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /Users/janitsharma/anaconda3/envs/ai_text_detection_env/lib/python3.11/site-packages (from transformers>=4.30.0->-r requirements.txt (line 7)) (0.36.0)
# Requirement already satisfied: regex!=2019.12.17 in /Users/janitsharma/anaconda3/envs/ai_text_detection_env/lib/python3.11/site-packages (from transformers>=4.30.0->-r requirements.txt (line 7)) (2025.11.3)
# Requirement already satisfied: requests in /Users/janitsharma/anaconda3/envs/ai_text_detection_env/lib/python3.11/site-packages (from transformers>=4.30.0->-r requirements.txt (line 7)) (2.32.5)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /Users/janitsharma/anaconda3/envs/ai_text_detection_env/lib/python3.11/site-packages (from transformers>=4.30.0->-r requirements.txt (line 7)) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in /Users/janitsharma/anaconda3/envs/ai_text_detection_env/lib/python3.11/site-packages (from transformers>=4.30.0->-r requirements.txt (line 7)) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in /Users/janitsharma/anaconda3/envs/ai_text_detection_env/lib/python3.11/site-packages (from transformers>=4.30.0->-r requirements.txt (line 7)) (4.67.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /Users/janitsharma/anaconda3/envs/ai_text_detection_env/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.34.0->transformers>=4.30.0->-r requirements.txt (line 7)) (1.2.0)
# Requirement already satisfied: six>=1.5 in /Users/janitsharma/anaconda3/envs/ai_text_detection_env/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas>=2.0.0->-r requirements.txt (line 2)) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/janitsharma/anaconda3/envs/ai_text_detection_env/lib/python3.11/site-packages (from sympy>=1.13.3->torch>=2.0.0->-r requirements.txt (line 1)) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/janitsharma/anaconda3/envs/ai_text_detection_env/lib/python3.11/site-packages (from jinja2->torch>=2.0.0->-r requirements.txt (line 1)) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/janitsharma/anaconda3/envs/ai_text_detection_env/lib/python3.11/site-packages (from requests->transformers>=4.30.0->-r requirements.txt (line 7)) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/janitsharma/anaconda3/envs/ai_text_detection_env/lib/python3.11/site-packages (from requests->transformers>=4.30.0->-r requirements.txt (line 7)) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/janitsharma/anaconda3/envs/ai_text_detection_env/lib/python3.11/site-packages (from requests->transformers>=4.30.0->-r requirements.txt (line 7)) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/janitsharma/anaconda3/envs/ai_text_detection_env/lib/python3.11/site-packages (from requests->transformers>=4.30.0->-r requirements.txt (line 7)) (2025.11.12)
# Note: you may need to restart the kernel to use updated packages.

# %%
# !python inference.py --checkpoint checkpoints/baseline.pt
# Out:
# Using device: cpu
# Loading model from: checkpoints/baseline.pt
# Model loaded. Enter text to classify (q to quit):
#
# >>> ^C
